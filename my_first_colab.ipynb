# %% [markdown]
# <a href="https://colab.research.google.com/github/asayee36-dot/EDU-AI-Training/blob/main/my_first_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
 "cells": [
  {
   "cell_type": "code",
   "source": [
    "print(\"Hello from Google Colab!\")"
   ]
  }
 ]
}
# Out:
# {'cells': [{'cell_type': 'code',
#    'source': ['print("Hello from Google Colab!")']}]}

# %%
print("yezarew ken des ylal")
# Out:
#   File "/tmp/ipykernel_1468/3528537717.py", line 1
#     yezarew ken des ylal
#             ^
# SyntaxError: invalid syntax

# %%
"The training today was excellent!"
# Out:
# 'The training today was excellent!'
